# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
##username = 'shihwesley'
##repository = 'CMPE257'

# %%
##%cd /content/drive/MyDrive/Teams/Petabyte\ Transformers/Code

# %%
##!git clone https://{git_token}@github.com/{username}/{repository}

# %%
# %cd /content/drive/MyDrive/Teams/Petabyte\ Transformers/Code/CMPE257
# Out:
# /content/drive/.shortcut-targets-by-id/1gMjREhmIs7NfuwoVW9P-PT6Lq3l-oczL/Teams/Petabyte Transformers/Code/CMPE257

# %%
# !git config --global user.email "shih.wesley@gmail.com"
# !git config --global user.name "Wesley Shih"

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git add .

# %%
# !git commit -m "fifth push from colab to github"
# Out:
# [main 8961d0f] fifth push from colab to github
#  1 file changed, 1 deletion(-)
#  delete mode 100644 Github_init.ipynb

# %%
# !git push
# Out:
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (2/2), 240 bytes | 80.00 KiB/s, done.
# Total 2 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/shihwesley/CMPE257
#    f3cddc6..8961d0f  main -> main

# %%
# !git config --list
# Out:
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# filter.lfs.clean=git-lfs clean -- %f
# user.email=shih.wesley@gmail.com
# user.name=Wesley Shih
# remote.origin.url=https://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@github.com/shihwesley/CMPE257
